# %%
# !conda create -y -n hdbscan_env -c conda-forge python=3.11 hdbscan ipykernel

# !conda run -n hdbscan_env python -m ipykernel install --user --name hdbscan_env --display-name "Python (hdbscan_env)"
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: C:\Users\ajosan\.conda\envs\hdbscan_env
#
#   added / updated specs:
#     - hdbscan
#     - ipykernel
#     - python=3.11
#
#
# The following NEW packages will be INSTALLED:
#
#   asttokens          conda-forge/noarch::asttokens-3.0.0-pyhd8ed1ab_1
#   bzip2              conda-forge/win-64::bzip2-1.0.8-h2466b09_7
#   ca-certificates    conda-forge/noarch::ca-certificates-2025.8.3-h4c7d964_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_1
#   comm               conda-forge/noarch::comm-0.2.3-pyhe01879c_0
#   cpython            conda-forge/noarch::cpython-3.11.13-py311hd8ed1ab_0
#   debugpy            conda-forge/win-64::debugpy-1.8.16-py311h5dfdfe8_0
#   decorator          conda-forge/noarch::decorator-5.2.1-pyhd8ed1ab_0
# ...

# %%
# %pip install hdbscan
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
